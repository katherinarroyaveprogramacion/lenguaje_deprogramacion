# %% [markdown]
# <a href="https://colab.research.google.com/github/katherinarroyaveprogramacion/lenguaje_deprogramacion/blob/main/Actividad_en_clase_19_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simulacion basica de inversion
#
# ##vamos a simular un proyecto de inversion

# %% [markdown]
# #Declarar las variables financieras

# %%
Inversion_inicial=50000000 # Esta variable es de tipo entero
tasa_descuento=0.10 #Esta variables es <class 'float'>

# %%
#definiendo los flujos
flujo_1=1500000
flujo_2=1800000
flujo_3=1200000

# %%
#verificando el valor que tiene la variable
print(type(Inversion_inicial))
print(type(tasa_descuento))
print(type(flujo_1))
print(type(flujo_2))
print(type(flujo_3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# #Operacion basica financiera

# %%
total_flujos = flujo_1 + flujo_2 + flujo_3

# %%
print("total de flujos recibidos", total_flujos)
# Out:
# total de flujos recibidos 4500000

# %%
print(type(total_flujos))
# Out:
# <class 'int'>

# %% [markdown]
# #Comparaciones

# %%
proyecto_rentable = total_flujos > Inversion_inicial

# %%
print(type(proyecto_rentable))
# Out:
# <class 'bool'>

# %%
nombre_proyecto = "Inversion mia"  #(string)
#rentabilidad_esperada: (float)
#numero_inevrsionistas (int)
#proyecto_aprobado (bool)

type(nombre_proyecto)
# Out:
# str

# %% [markdown]
# #Inversion mia

# %%
Inversion_inicial = 50000000
nombre_proyecto = "Inversion mia"
rentanbilidad_esperada = 200000
numero_inversionistas = 10
